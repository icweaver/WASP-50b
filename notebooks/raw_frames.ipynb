# %% [markdown]
# # 2D Spectra

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import glob as glob
import matplotlib as mpl
import matplotlib.patheffects as PathEffects
import matplotlib.pyplot as plt
import matplotlib.transforms as transforms
import numpy as np
import pandas as pd
import seaborn as sns

import corner
import json
import pathlib
import pickle
import utils
import warnings

from astropy import constants as const
from astropy import units as uni
from astropy.io import ascii, fits
from astropy.time import Time
from mpl_toolkits.axes_grid1 import ImageGrid

# Default figure dimensions
FIG_WIDE = (11, 5)
FIG_LARGE = (8, 11)

# Figure style
sns.set(style="ticks", palette="colorblind", color_codes=True, context="talk")
params = utils.plot_params()
plt.rcParams.update(params)

# %% [markdown]
# ## [Dowload data](https://www.dropbox.com/sh/10zzp0fsjdijwg7/AADSAOUxQvyc_8EZlnzMzdXSa?dl=1)

# %% [markdown]
# Unzip this into a folder named `data` in the same level as this notebook

# %% [markdown]
# ## Plot

# %%
data_dir = "data/raw_frames"
data_dict = {
    "Transit_1": {
        "path": f"{data_dir}/ut131219",
        "ift": "0024", # field
        #"ift": "0026", # sci
        "sky_ap": 25,
    },
#     "transit_2": {
#         "path": f"{data_dir}/ut170609",
#         "ift": "0183",
#         "sky_ap": 25,
#     },
#     "transit_3": {
#         "path": f"{data_dir}/ut180603",
#         "ift": "0076",
#         "sky_ap": 25,
#     },
}

for transit, transit_info in data_dict.items():
    dirpath = transit_info["path"]
    fname = f"ift{transit_info['ift']}"
    sky_ap = transit_info["sky_ap"]
    fig, im = utils.plot_chips(
        dirpath,
        fname,
        target="WASP50",
        vmin=0,
        vmax=2_000,
        sky_ap=0,
        spec_ap=0,
    )

    # Save
    title = f"raw_frame_{transit}"
    #utils.savefig(f"../paper/figures/raw_frames/{title}.pdf")

# %%
data_dict
# Out:
# {'Transit_1': {'path': 'data/raw_frames/ut131219',
#   'ift': '0026',
#   'sky_ap': 25}}

# %%
with open(f"data/raw_frames/ut131219/ift0025c1.fits", "rb") as f:
        hdu = fits.open(f)

# %%
hdu[0].header
# Out:
# WARNING: VerifyWarning: Verification reported errors: [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'VGAUGE' is not FITS standard (invalid value string: '0.00e+00         / vacuum gauge [mbar]').  Fixed 'VGAUGE' card to meet the FITS standard. [astropy.io.fits.verify]
# WARNING: VerifyWarning: Note: astropy.io.fits uses zero-based indexing.
#  [astropy.io.fits.verify]
# WARNING: VerifyWarning: Card 'IONPUMP' is not FITS standard (invalid value string: '8.58e-07         / ion-pump gauge [mbar]').  Fixed 'IONPUMP' card to meet the FITS standard. [astropy.io.fits.verify]
# SIMPLE  =                    T
# BITPIX  =                   16
# NAXIS   =                    2
# NAXIS1  =                 2112
# NAXIS2  =                 4160
# BSCALE  =           1.00000000         / real=bzero+bscale*value
# BZERO   =       32768.00000000
# BUNIT   = 'DU/PIXEL'
# ORIGIN  = 'LCO/OCIW'
# OBSERVER= 'Lopez-Morales'              / observer name
# TELESCOP= 'Baade_Mag_1'                / telescope
# SITENAME= 'LCO'
# SITEALT =                 2400         / meters
# SITELAT =            -29.01423
# SITELONG=            -70.69242
# TIMEZONE=                    4
# DATE-OBS= '2013-12-19'                 / UT date (start)
# UT-DATE = '2013-12-19'                 / UT date (start)
# UT-TIME = '01:39:58'                   / UT time (start) 5998 seconds
# UT-END  = '01:40:03'                   / UT time (end) 6003 seconds
# LC-TIME = '22:39:58'                   / local time (start) 81598 seconds
# NIGHT   = '18Dec2013'                  / local night
# INSTRUME= 'IMACS Short-Camera'         / instrument name
# CCD-TYPE= 'E2V'                        / CCD type
# DEWAR   = 'Mosaic2'                    / Dewar
# SCALE   =                0.200         / x 0.999 arcsec/pixel
# EGAIN   =                 1.00         / electrons/DU (nominal)
# ENOISE  =                 5.50         / electrons/read (nominal)
# CDSTIME =                   80         / CDS time
# CCDGAIN = 'High'                       / CCD gain
# NCHIPS  =                    8
# CHIP    =                    1         / chip-ID
# CHOFFX  =              639.386         / x-offset [arcsec]
# CHOFFY  =             -417.792         / y-offset [arcsec]
# RA      = ' 02:54:59.7'                / right ascension
# RA-D    =           43.7485833         / degrees
# DEC     = '-10:57:03.7'                / declination
# DEC-D   =          -10.9510278         / degrees
# EQUINOX =           2000.00000         / of above coordinates
# ASECS   =                  0.0         / arcseconds
# DSECS   =                  0.0         / arcseconds
# EPOCH   =           2013.96450         / epoch (start)
# AIRMASS =                1.052         / airmass (start)
# TEL-ELEV=                71.81         / telescope elevation
# ST      =              10112.8         / sidereal time: 02:48:32 (start)
# HA      =             -0.10746         / hours (start)
# HA-STR  = 'E00:06:26'                  / hour angle (start)
# GRAV-A1 =              -102.88         / IMACS/4 gravity angle (start)
# GRAV-A2 =              -102.96         / IMACS/4 gravity angle (end)
# GRAV-MIN=              -102.96         / IMACS/4 gravity angle (min)
# GRAV-MAX=              -102.88         / IMACS/4 gravity angle (max)
# ROTANGLE=               223.48         / rotator offset angle
# ROTATORE=                38.52         / rotator encoder angle
# G-SEEING=                 0.00         / guider seeing
# CAL-LAMP= 'none'                       / calibration lamp(s)
# FILENAME= 'ift0025c1'
# OBJECT  = 'Field image'                / object name
# COMMENT =                              / comment
# EXPTYPE = 'Object'                     / exposure type
# EXPTIME =                5.000         / exposure time
# BINNING = '1x1'                        / binning
# FILTER  = 'Spectroscopic2'             / filter
# DISPERSR= 'f/2-Imaging'                / disperser
# G-ANGLE =                0.000         / grating angle
# SLITMASK= 'wasp50s_2860'               / slit-mask
# GISMO   = 'none'                       / GISMO mask
# DETFOCUS=               7058.9         / detector-focus
# L05FOCUS=                  0.0         / L05-focus
# NSHUFFLE=                    0         / physical pixels
# NOD-RA  =                  0.0         / n/a
# NOD-DEC =                  0.0         / n/a
# STRDL-O1=                    0         / n/a
# STRDL-ON=                    0         / n/a
# STRDL-O2=                    0         / n/a
# DWELTIME=                  0.0         / dwell time
# NCYCLES =                    0         / shuffle cycles
# MMTF-X  =                    0         / Etalon-X (parallelism)
# MMTF-Y  =                    0         / Etalon-Y (parallelism)
# MMTF-Z  =                    0         / Etalon-Z (spacing)
# MMTF-CX =                   -1         / Etalon-X (coarse)
# MMTF-CY =                    0         / Etalon-Y (coarse)
# MMTF-CZ =                   -2         / Etalon-Z (coarse)
# MMTF-FX =                 7.11         / Etalon-X (fine)
# MMTF-FY =                 6.80         / Etalon-Y (fine)
# MMTF-FZ =                 4.10         / Etalon-Z (fine)
# MMTF-QX =                 4.30         / Etalon-X (quad-balance)
# MMTF-QY =                 4.07         / Etalon-Y (quad-balance)
# MMTF-QZ =                 4.21         / Etalon-Z (quad-balance)
# SCRIPT  = 'none'                       / script file
# NLOOPS  =                    1         / # of loops per sequence
# LOOP    =                    1         / # within this sequence
# SPEED   = 'Turbo'                      / readout speed
# NOVERSCN=                   64         / overscan pixels
# NBIASLNS=                   64         / bias lines
# BIASSEC = '[2049:2112,1:4096]'         / NOAO: bias section
# DATASEC = '[1:2048,1:4096]'            / NOAO: data section
# DEWARORI= 'Normal'                     / dewar orientation
# SUBRASTR= 'none'                       / full frame
# TEMPCCD1=               -152.8         / CryoT  temperature
# TEMPCCD2=               -103.2         / Platen temperature
# TEMPCCD3=                -92.9         / Chip-3 temperature
# TEMPCCD4=               -100.8         / Platen temperature
# TEMPCCD5=               -102.6         / Platen temperature
# TEMPCCD6=               -156.0         / CryoT  temperature
# TEMPCCD7=               -100.0         / Platen temperature
# TEMPCCD8=                -94.5         / Chip-8 temperature
# TEMPSTR =                 18.5         / structure temperature [C]
# VGAUGE  =             0.00E+00 / vacuum gauge [mbar]
# IONPUMP =             8.58E-07 / ion-pump gauge [mbar]
# SOFTWARE= 'Version 3.2.3 (Dec  5 2013, 16:23:41)'
# FITSVERS= '3.2.2'                      / FITS header version
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT
# COMMENT

# %% [markdown]
# ## LDSS3

# %%
def plot_chips_LDSS3(dirpath, fnumber):
    with open(f"{dirpath}/{fnumber}c1.fits", "rb") as f:
        data_left = fits.open(f)[0].data
    with open(f"{dirpath}/{fnumber}c2.fits", "rb") as f:
        data_right = fits.open(f)[0].data

    fig, axes = plt.subplots(1, 2, sharey=True)
    ax_left, ax_right = axes

    ax_left.imshow(data_left, vmin=0, vmax=2_000)
    ax_right.imshow(data_right, vmin=0, vmax=2_000)

    fig.tight_layout()
    
    fig.suptitle(fnumber)

# %%
plot_chips_LDSS3("/home/mango/data/WASP50/ut150927_LDSS3", "ccd0602") # field

# %%
plot_chips_LDSS3("/home/mango/data/WASP50/ut150927_LDSS3", "ccd0603") # thru mask

# %%
plot_chips_LDSS3("/home/mango/data/WASP50/ut150927_LDSS3", "ccd0606") # sci
